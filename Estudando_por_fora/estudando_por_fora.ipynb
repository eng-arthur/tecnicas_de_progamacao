# %% [markdown]
# # 📘 Anotações de Estudo – C++
#
# ## Introdução
#
# Este notebook foi criado para registrar anotações, exemplos de código e conceitos importantes sobre a linguagem de programação C++. O objetivo é organizar o aprendizado de forma clara, permitindo consultar posteriormente conceitos fundamentais da linguagem.
#
# C++ é uma linguagem de programação de propósito geral amplamente utilizada em desenvolvimento de software, sistemas embarcados, jogos e aplicações de alto desempenho.
#
# ## Objetivos deste notebook
#
# * Registrar conceitos fundamentais da linguagem C++
# * Testar pequenos trechos de código
# * Documentar exemplos e exercícios resolvidos
# * Facilitar a revisão dos conteúdos estudados
#
# ## Conteúdos que serão abordados
#
# * Estrutura básica de um programa em C++
# * Variáveis e tipos de dados
# * Operadores
# * Estruturas condicionais
# * Estruturas de repetição
# * Funções
# * Classes e programação orientada a objetos
#
# ---
#
# ## Primeiro exemplo em C++
#
# Abaixo está um exemplo simples de um programa em C++ que imprime uma mensagem na tela.

# %%
#include <iostream>
using namespace std;

int main() {
    cout << "Hello, World!" << endl;
    return 0;
}
